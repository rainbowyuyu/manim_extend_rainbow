# %%
from yty_manim.application.page_replacement import *
from yty_manim.basic_unit.squ_tex import *
from yty_manim.basic_unit.screen_cycle import *
from manim import *

# %%
# %%manim -qh -v WARNING DeBug
# class DeBug(Scene):
#     def construct(self):
#         input_lst = [7,0,1,2,0,3,0,4,2,3,0,3,2,1,2,0,1,7,0,1," "]
#         s = ClockPageReplacement(input_lst,page_frame_num=5)
#         self.add(s)
# Out:
# Manim Community v0.19.0

# %%
# %%manim -qh -v WARNING PageTest
# class PageTest(Scene):
#     def construct(self):
#         title = Text("OPT").set_color_by_gradient(gradient_dict["favourite"]).to_edge(UL)
#         input_lst = [7,0,1,2,0,3,4,2," "]
#         p = OptPageReplacement(input_lst,page_frame_num=3)
#         self.add(p,title)
#         self.wait()
#         for i in range(len(input_lst)-1):
#             p.step_on(self,i,0.5)
# Out:
# Manim Community v0.19.0
# <video src="media\jupyter\PageTest@2025-05-17@02-32-21.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qh -v WARNING PageInit
# class PageInit(Scene):
#     def construct(self):
#         input_lst = [7,0,1,2,0,3,0,4,2,3,0,3,2,1,2,0,1,7,0,1," "]
#         p = Page(input_lst,page_frame_num=3)
#         self.add(p)

# %%
# %%manim -qh -v WARNING ScreenTest
# class ScreenTest(Scene):
#     def construct(self):
#         text_list = [
#             "Hello World",
#             "Hell Worl",
#             "Hel Wor",
#             "He Wo",
#         ]
#         s = ScreenCycle(text_list)
#         self.add(s)
#         self.play(s.animate.step_forward())
#         self.play(s.animate.step_forward())
#         self.play(s.animate.set_to_edge(UL))
#         self.play(s.animate.set_back())
#         self.play(s.animate.step_forward())
#         self.play(s.animate.step_forward())
#         self.play(s.animate.step_forward())

# %%
# %%manim -qh -v WARNING StackTest
# class StackTest(Scene):
#     def construct(self):
#         s = SquTexSlide("0",font=text_font[0],**typedict["default_type"]).shift(LEFT*2)
#         color_lst = [GREEN,RED,PURPLE,YELLOW]
#         self.add(s)
#         for i in range(4):
#             self.play(
#                 *s.push(i+1),
#                 s[-1].animate.set_color(color_lst[i])
#             )
#             self.play(*s.slide_fade(-1))
# Out:
# Manim Community v0.19.0
# <video src="media\jupyter\StackTest@2025-04-10@17-27-52.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qh -v WARNING StackTex
# class StackTex(Scene):
#     def construct(self):
#         t = ["\\frac{1}{3}" for i in range(6)]
#         print(len(t))
#         s = SquTex(t,text_type=MathTex)
#         self.add(s)
# Out:
# 6

# %%
# %%manim -qh -v WARNING DrawLogo
# class DrawLogo(Scene):
#     def construct(self):
#         logo = SVGMobject(r"C:\Users\rainbow_yu\Desktop\logo\logo.svg").set_color(WHITE)
#         self.add(logo)

# %%
# %%manim -qh -v WARNING ThreeDMoebiusTorus
#
# from manim import *
#
#
# class ThreeDMoebiusTorus(ThreeDScene):
#     def construct(self):
#         # 定义扭曲成莫比乌斯环形状的圆环柱体的参数方程
#         def moebius_torus_function(u, v):
#             R = 2  # 大环半径
#             r = 1  # 小环半径
#             # 调整参数方程以实现扭曲效果
#             x = (R + r * np.cos(v)) * np.cos(u)
#             y = (R + r * np.cos(v)) * np.sin(u)
#             # 在 z 方向引入扭转
#             z = r * np.sin(v) * np.sin(u / 2)
#             return np.array([x, y, z])
#
#         # 创建莫比乌斯环形状的圆环柱体表面
#         moebius_torus = Surface(
#             moebius_torus_function,
#             u_range=[0, TAU],
#             v_range=[0, TAU],
#             checkerboard_colors=[BLUE_D, BLUE_E],
#             resolution=(32, 16)
#         )
#
#         # 设置相机视角
#         self.set_camera_orientation(phi=75 * DEGREES, theta=-90 * DEGREES)
#         self.add(moebius_torus)
#         # # 添加莫比乌斯环形状的圆环柱体到场景
#         # self.play(Create(moebius_torus))
#         #
#         # # 旋转莫比乌斯环形状的圆环柱体
#         # self.begin_ambient_camera_rotation(rate=0.1)
#         # self.wait(10)
# Out:
# Manim Community v0.19.0

# %%
from manim import *

# %%
# %%manim -qh -v WARNING MatrixDeterminant
#
# class MatrixDeterminant(Scene):
#     def construct(self):
#         # 定义矩阵
#         matrix_data = [
#             [-18, 23, 39],
#             [42, 96, 87],
#             [33, 15, -54]
#         ]
#
#         # 创建矩阵对象
#         matrix = Matrix(matrix_data)
#         matrix_title = Text("3×3矩阵的行列式计算", font_size=24).to_edge(UP)
#
#         # 显示矩阵和标题
#         self.play(Write(matrix_title))
#         self.play(Create(matrix))
#         self.wait(1)
#
#         # 移动矩阵到左侧
#         self.play(matrix.animate.to_edge(LEFT))
#         self.wait(0.5)
#
#         # 展示行列式公式
#         formula = MathTex(
#             r"\begin{vmatrix} a & b & c \\ d & e & f \\ g & h & i \end{vmatrix}",
#             r"=",
#             r"a \cdot \begin{vmatrix} e & f \\ h & i \end{vmatrix}",
#             r"- b \cdot \begin{vmatrix} d & f \\ g & i \end{vmatrix}",
#             r"+ c \cdot \begin{vmatrix} d & e \\ g & h \end{vmatrix}"
#         ).scale(0.8).to_edge(RIGHT)
#
#         self.play(Write(formula))
#         self.wait(2)
#
#         # 替换为实际数值
#         actual_formula = MathTex(
#             r"\begin{vmatrix} -18 & 23 & 39 \\ 42 & 96 & 87 \\ 33 & 15 & -54 \end{vmatrix}",
#             r"=",
#             r"-18 \cdot \begin{vmatrix} 96 & 87 \\ 15 & -54 \end{vmatrix}",
#             r"- 23 \cdot \begin{vmatrix} 42 & 87 \\ 33 & -54 \end{vmatrix}",
#             r"+ 39 \cdot \begin{vmatrix} 42 & 96 \\ 33 & 15 \end{vmatrix}"
#         ).scale(0.8).to_edge(RIGHT)
#
#         self.play(Transform(formula, actual_formula))
#         self.wait(2)
#
#         # 计算第一个2x2行列式
#         det1 = MathTex(
#             r"\begin{vmatrix} 96 & 87 \\ 15 & -54 \end{vmatrix}",
#             r"=",
#             r"96 \cdot (-54) - 87 \cdot 15",
#             r"=",
#             r"-5184 - 1305",
#             r"=",
#             r"-6489"
#         ).scale(0.7).next_to(matrix, DOWN, buff=1).shift(RIGHT*2)
#
#         self.play(Write(det1[:3]))
#         self.wait(1)
#         self.play(Write(det1[3:5]))
#         self.wait(1)
#         self.play(Write(det1[5:]))
#         self.wait(2)
#
#         # 计算第二个2x2行列式
#         det2 = MathTex(
#             r"\begin{vmatrix} 42 & 87 \\ 33 & -54 \end{vmatrix}",
#             r"=",
#             r"42 \cdot (-54) - 87 \cdot 33",
#             r"=",
#             r"-2268 - 2871",
#             r"=",
#             r"-5139"
#         ).scale(0.7).next_to(det1, DOWN, buff=0.7)
#
#         self.play(Write(det2[:3]))
#         self.wait(1)
#         self.play(Write(det2[3:5]))
#         self.wait(1)
#         self.play(Write(det2[5:]))
#         self.wait(2)
#
#         # 计算第三个2x2行列式
#         det3 = MathTex(
#             r"\begin{vmatrix} 42 & 96 \\ 33 & 15 \end{vmatrix}",
#             r"=",
#             r"42 \cdot 15 - 96 \cdot 33",
#             r"=",
#             r"630 - 3168",
#             r"=",
#             r"-2538"
#         ).scale(0.7).next_to(det2, DOWN, buff=0.7)
#
#         self.play(Write(det3[:3]))
#         self.wait(1)
#         self.play(Write(det3[3:5]))
#         self.wait(1)
#         self.play(Write(det3[5:]))
#         self.wait(2)
#
#         # 汇总结果
#         final_calc = MathTex(
#             r"=& -18 \cdot (-6489) - 23 \cdot (-5139) + 39 \cdot (-2538) \\",
#             r"=& 116802 + 118197 - 98982 \\",
#             r"=& 136017"
#         ).scale(0.8).next_to(det3, DOWN, buff=0.7).shift(LEFT*0.5)
#
#         self.play(Write(final_calc[0]))
#         self.wait(1)
#         self.play(Write(final_calc[1]))
#         self.wait(1)
#         self.play(Write(final_calc[2]))
#         self.wait(2)
#
#         # 最终结果框
#         result_box = SurroundingRectangle(final_calc[2], buff=0.2, color=YELLOW)
#         result_text = Text("行列式值 = 136017", font_size=24).next_to(result_box, DOWN)
#
#         self.play(Create(result_box))
#         self.play(Write(result_text))
#         self.wait(3)
# Out:
# Manim Community v0.19.0
# <video src="media\jupyter\MatrixDeterminant@2025-04-21@21-02-10.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
class Book(VGroup):
    def __init__(
            self,
            title,
            index=0,
            fill_color=GRAY,
            stroke_color=GRAY_E
    ):
        super().__init__()
        self.title = title
        self.index = index

        t = VGroup()
        for i in self.title:
            t.add(Text(i))
        t.arrange(DOWN, buff=0.1)

        depth_points = [
            np.array((0.25, -1, 0.0)),
            np.array((0.6, -0.25, 0.0)),
            np.array((0.6, -0.25, 0.0))+ 2*UP,
            np.array((0.25, -1, 0.0)) + 2*UP,
        ]

        # 创建平行四边形
        depth_pol = Polygon(
            *depth_points,
            fill_color=fill_color,
            stroke_color=stroke_color,
            fill_opacity=1,
            stroke_opacity=1,
            stroke_width=2
        )

        height_points = [
            np.array((-0.25, 1, 0.0)),
            np.array((0.1, 1.75, 0.0)),
            np.array((0.1, 1.75, 0.0))+ 0.5*RIGHT,
            np.array((-0.25, 1, 0.0)) + 0.5*RIGHT,
        ]

        height_pol = Polygon(
            *height_points,
            fill_color="#ffeebb",
            stroke_color=stroke_color,
            fill_opacity=1,
            stroke_opacity=1,
            stroke_width=2
        )

        self.add(
            depth_pol,
            height_pol,
            Rectangle(
                fill_color=fill_color,
                stroke_color=stroke_color,
                fill_opacity=1,
                stroke_opacity=1,
                height=2,
                width=0.5,
            ),
            t.shift(DOWN*0.4).scale(0.8),

        )
        self.set_z_index(self.index)

# %%
# %%manim -qh -v WARNING BookShape
#
# class BookShape(Scene):
#     def construct(self):
#         b = Book("...",0,BLUE,BLUE_E)
#         b2 = Book("CV",1,GREEN,GREEN_E)
#         self.add(b.shift(LEFT*0.5),b2)
# Out:
# Manim Community v0.19.0

# %%
class Directory(VGroup):
    def __init__(
            self,
            title: list,
            **kwargs,
    ):
        super().__init__()
        self.current = -1

        text = VGroup()
        dot = VGroup()
        lines = VGroup()
        for i in range(len(title)):
            t = Text(title[i], **kwargs).scale(0.8).set_color(GRAY)
            text.add(t)
            d = Dot().scale(2)
            dot.add(d)
        text.arrange(DOWN, buff=0.8, aligned_edge=LEFT).to_edge(LEFT, buff=1.5)
        for i in range(len(dot)):
            dot[i].next_to(text[i], LEFT, buff=0.5).set_color(gradient_dict['rainbow_color'][i%7])

        for i in range(len(title)-1):
            l = Line(dot[i].get_center(), dot[i+1].get_center())
            l.set_color_by_gradient([gradient_dict['rainbow_color'][i%7+1],gradient_dict['rainbow_color'][i%7]])
            lines.add(l)

        dot.set_z_index(1)
        self.add(text,dot,lines)

    def step_forward(self):
        if self.current != -1:
            self[0][self.current].scale(0.8).set_color(GRAY)

# %%
# %%manim -qh -v WARNING DirectoryShow
# title = [
#                 "页面与页面置换",
#                 "抖动与belady",
#                 "页面置换算法",
#                 "栈结构",
#                 "编程代码"
#         ]
# class DirectoryShow(Scene):
#     def construct(self):
#         d = Directory(title,font = text_font[0])
#         self.add(d)
# Out:
# Manim Community v0.19.0

# %%
# %%manim -qh -v WARNING Flow
# class Flow(Scene):
#     def construct(self):
#         pass
# Out:
# Manim Community v0.19.0

# %%
# %%manim -qh -v WARNING MatrixExample
#
# class MatrixExample(Scene):
#     def construct(self):
#         # 渲染 LaTeX 矩阵
#         matrix_tex = MathTex(
#             r"\begin{bmatrix} -18 & 23 & 39 \\ 42 & 96 & 87 \\ 33 & 15 & -54 \end{bmatrix}"
#         )
#         self.add(matrix_tex)
# Out:
# Manim Community v0.19.0
