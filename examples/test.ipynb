# %%
from yty_manim.application.page_replacement import *
from yty_manim.basic_unit.squ_tex import *
from yty_manim.basic_unit.screen_cycle import *
from manim import *
# Out:
# Manim Community v0.18.0

# %%
# %%manim -qh -v WARNING DeBug
# class DeBug(Scene):
#     def construct(self):
#         input_lst = [7,0,1,2,0,3,0,4,2,3,0,3,2,1,2,0,1,7,0,1," "]
#         s = ClockPageReplacement(input_lst,page_frame_num=5)
#         self.add(s)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_cell_magic('manim', '-qh -v WARNING DeBug', 'class DeBug(Scene):\n    def construct(self):\n        input_lst = [7,0,1,2,0,3,0,4,2,3,0,3,2,1,2,0,1,7,0,1," "]\n        s = ClockPageReplacement(input_lst,page_frame_num=5)\n        self.add(s)\n')
#
# File E:\manim_extend_rainbow\.venv\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File E:\manim_extend_rainbow\.venv\Lib\site-packages\manim\utils\ipython_magic.py:141, in ManimMagic.manim(self, line, cell, local_ns)
#     139     SceneClass = local_ns[config["scene_names"][0]]
#     140     scene = SceneClass(renderer=renderer)
# --> 141     scene.render()
#     142 finally:
#     143     # Shader cache becomes invalid as the context is destroyed
#     144     shader_program_cache.clear()
#
# File E:\manim_extend_rainbow\.venv\Lib\site-packages\manim\scene\scene.py:223, in Scene.render(self, preview)
#     221 self.setup()
#     222 try:
# --> 223     self.construct()
#     224 except EndSceneEarlyException:
#     225     pass
#
# File <string>:4, in construct(self)
#
# File E:\manim_extend_rainbow\yty_manim\application\page_replacement.py:426, in ClockPageReplacement.__init__(self, page_lst, page_frame_num, **kwargs)
#     420 def __init__(
#     421         self,
#     422         page_lst: list,
#     423         page_frame_num: int = 5,
#     424         **kwargs
#     425 ):
# --> 426     super().__init__(page_lst, page_frame_num, need_stack=True, **kwargs)
#     428     # 定位栈指针
#     429     self.pointer = Triangle(fill_opacity=0.5)
#
# File E:\manim_extend_rainbow\yty_manim\application\page_replacement.py:161, in PageReplacement.__init__(self, page_lst, page_frame_num, **kwargs)
#     155 def __init__(
#     156         self,
#     157         page_lst: list,
#     158         page_frame_num: int = 3,
#     159         **kwargs,
#     160 ):
# --> 161     super().__init__(page_lst, page_frame_num, **kwargs)
#     162     self.page_frame_lst = []
#     163     self.frame_expect = 0
#
# File E:\manim_extend_rainbow\yty_manim\application\page_replacement.py:68, in Page.__init__(self, page_lst, page_frame_num, one_step, color_lst, need_stack)
#      64     raise ValueError("页框数必须小于颜色数")
#      66 self.DEFAULT_STACK_SHIFT = UP * 2 + self.page_frame_num / 2 * LEFT
# ---> 68 self._construct()
#      69 self._add_to_page()
#
# File E:\manim_extend_rainbow\yty_manim\application\page_replacement.py:87, in Page._construct(self)
#      85 self.opt_frame = VGroup()
#      86 for i in range(self.page_frame_num):
# ---> 87     self.page_frame.change_square(i, color=self.color_lst[i])
#      88     opt_squ = Square(side_length=1).set_color(self.color_lst[i]).move_to(self.pages[i]).scale(self.one_step[1])
#      89     self.opt_frame.add(opt_squ)
#
# File E:\manim_extend_rainbow\yty_manim\basic_unit\squ_tex.py:184, in SquTex.change_square(self, *args, **kwargs)
#     176 """
#     177 直接改变方块项的参数
#     178 :param args: 可变参数，记录了改变样式的位置
#     179 :param kwargs: 可变字典，记录了改变的样式
#     180 :return: self
#     181 """
#     183 for i in args:
# --> 184     self[i][0].set(**kwargs)
#     185 return self
#
# File E:\manim_extend_rainbow\.venv\Lib\site-packages\manim\mobject\mobject.py:2202, in Mobject.__getitem__(self, value)
#    2200     GroupClass = self.get_group_class()
#    2201     return GroupClass(*self_list.__getitem__(value))
# -> 2202 return self_list.__getitem__(value)
#
# IndexError: list index out of range

# %%
# %%manim -qh -v WARNING PageTest
# class PageTest(Scene):
#     def construct(self):
#         title = Text("OPT").set_color_by_gradient(gradient_dict["favourite"]).to_edge(UL)
#         input_lst = [7,0,1,2,0,3,0,4,2,3,0,3,2,1,2,0,1,7,0,1," "]
#         p = OptPageReplacement(input_lst,page_frame_num=3)
#         self.add(p,title)
#         self.wait()
#         for i in range(len(input_lst)-1):
#             p.step_on(self,i,0.5)
# Out:
# <video src="media\jupyter\PageTest@2025-03-06@11-49-56.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qh -v WARNING PageInit
# class PageInit(Scene):
#     def construct(self):
#         input_lst = [7,0,1,2,0,3,0,4,2,3,0,3,2,1,2,0,1,7,0,1," "]
#         p = Page(input_lst,page_frame_num=3)
#         self.add(p)

# %%
# %%manim -qh -v WARNING ScreenTest
# class ScreenTest(Scene):
#     def construct(self):
#         text_list = [
#             "Hello World",
#             "Hell Worl",
#             "Hel Wor",
#             "He Wo",
#         ]
#         s = ScreenCycle(text_list)
#         self.add(s)
#         self.play(s.animate.step_forward())
#         self.play(s.animate.step_forward())
#         self.play(s.animate.set_to_edge(UL))
#         self.play(s.animate.set_back())
#         self.play(s.animate.step_forward())
#         self.play(s.animate.step_forward())
#         self.play(s.animate.step_forward())

# %%
# %%manim -qh -v WARNING StackTest
# class StackTest(Scene):
#     def construct(self):
#         s = SquTexSlide("0",font=text_font[0],**typedict["default_type"]).shift(LEFT*2)
#         color_lst = [GREEN,RED,PURPLE,YELLOW]
#         self.add(s)
#         for i in range(4):
#             self.play(
#                 *s.push(i+1),
#                 s[-1].animate.set_color(color_lst[i])
#             )
#             self.play(*s.slide_fade(-1))
# Out:
# <video src="media\jupyter\StackTest@2025-02-07@22-05-56.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qh -v WARNING StackTex
# class StackTex(Scene):
#     def construct(self):
#         t = ["\\frac{1}{3}" for i in range(6)]
#         print(len(t))
#         s = SquTex(t,text_type=MathTex)
#         self.add(s)
# Out:
# 6

# %%
# %%manim -qh -v WARNING DrawLogo
# class DrawLogo(Scene):
#     def construct(self):
#         logo = SVGMobject(r"C:\Users\rainbow_yu\Desktop\logo\logo.svg").set_color(WHITE)
#         self.add(logo)
